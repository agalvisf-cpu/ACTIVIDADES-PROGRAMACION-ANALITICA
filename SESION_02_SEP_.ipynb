# %%
Nota = 4.0
if Nota >=  4.5:
  print ("excelente")
elif Nota >= 4.0:
  print("Muy buen desempeño")
elif Nota >= 3.0:
  print ("aprobado")
else:
  print("No Aprobado")
# Out:
# Muy buen desempeño

# %%
Nota = 4.0
if Nota >=  3.0:
  print ("aprobado")
elif Nota >= 4.0:
  print("Muy buen desempeño")
elif Nota >= 4.5:
  print ("excelente")
else:
  print("No Aprobado")
# Out:
# aprobado

# %% [markdown]
# * If: Si
# * elif: Otra condicion al If
# * Else: Contrario a IF
# OJO: El orden es importante, Python toma el primer valor que se cumple.

# %%
Usuario_activo= True
Tiene_permiso= True
if Usuario_activo and Tiene_permiso:
  print("Acceso Permitido")
else:
  print("Acceso Denegado")
# Out:
# Acceso Permitido

# %%
#Range toma el valor de N de Inicio y N de parada -1
for numero in range (4,10):
  print(numero)
# Out:
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#el 3er valor es el numero que se salta
for numero in range (1,10,2):
  print(numero)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for numero in range (1,11):
  if numero % 2 == 0:
    print (numero, "Es Par")
# Out:
# 2 Es Par
# 4 Es Par
# 6 Es Par
# 8 Es Par
# 10 Es Par

# %% [markdown]
# %2 logica de Python para definir si un numero es Par

# %%
#While: Mientras que

Clave_correcta = "ABC1234"
Clave=""

while Clave != Clave_correcta:
  Clave = input

# %%
for numero in range (1,8):
  if numero < 3:
    print (numero, "A")
  elif numero < 6:
    print (numero, "b")
  else:
    print (numero, "c")
# Out:
# 1 A
# 2 A
# 3 b
# 4 b
# 5 b
# 6 c
# 7 c

# %%
#float se usa para incluir dato numerico enteros y decimales
#input Genera el mensaje que le sigue y el cuadrito para que se pueda dijitar
for i in range (5):
  t = float (input('temperatura: '))
  if t < 18:
    print ("temperatura baja")
  elif t <= 25:
    print ("temperatura normal")
  else:
    print ("temperatura alta")
# Out:
# temperatura: 10.5
# temperatura baja
# temperatura: 5
# temperatura baja
# temperatura: 100
# temperatura alta
# temperatura: 101.2
# temperatura alta
# temperatura: 60
# temperatura alta

# %%
#Uso del Input
nombre = ""
print ("Su nombre es", nombre)
nombre = input ("Ingrese su nombre: ")
print ("Su nombre es", nombre)
# Out:
# Su nombre es
# Ingrese su nombre: Anyi
# Su nombre es Anyi
